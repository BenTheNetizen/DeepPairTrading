# %% [markdown]
# # Testing for Cointegration Between Ethereum and Bitcoin

# %%
# import statements
import pdb
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import scipy.optimize as spop

# Position Class 
"""
    Purpose: Records a singular trade's position data 
"""
class Position():
    def __init__(self, is_asset_1_shorted, entry_time, entry_price_1, entry_price_2, balance, bet_size):      
        self.is_asset_1_shorted = is_asset_1_shorted  # True if asset_1 is shorted, False if longed 
        self.trade_return = None                # holding period return 
        self.entry_time = entry_time 
        self.exit_time = None 
        self.entry_balance = balance 
        self.exit_balance = None 
        self.entry_price_1 = entry_price_1 
        self.entry_price_2 = entry_price_2
        self.exit_price_1 = None
        self.exit_price_2 = None 
        self.max_drawdown = None 
        self.max_drawup = None 
        self.bet_size = bet_size 
    def close_position(self, price_1, price_2, time):
        self.exit_time = time 
        self.exit_price_1 = price_1 
        self.exit_price_2 = price_2

        payoff = 0
        if self.is_asset_1_shorted:
            payoff += self.entry_price_1 - price_1 
            payoff += price_2 - self.entry_price_2
        else:
            payoff += price_1 - self.entry_price_1
            payoff += self.entry_price_2 - price_2
        
        self.trade_return = payoff / (self.entry_price_1 + self.entry_price_2)
        self.exit_balance = self.entry_balance + (self.bet_size * self.trade_return)
        print("TRADE PAYOFF: " + str(self.bet_size * self.trade_return))

# %%
# Useful functions
"""
price = np.array(btc_data['Open'])
time = np.array(btc_data.index)
"""

"""
    Purpose: Returns a Standard Deviation DataFrame based on the input data

    Inputs:
        data: A Pandas DataFrame Series
        period: length of the Standard Deviation
"""
def get_stdev(data, period):
    data_series = pd.Series(data)
    window = data_series.rolling(period)
    sd = window.std()

    sd_list = sd.tolist()

    df_sd = pd.DataFrame(sd_list, columns=['stdev'])
    df_sd['stdev'] = df_sd['stdev'].fillna(0)
    df_sd.index = data.index

    return df_sd.iloc[period:]['stdev']

"""
    Purpose: Returns a Simple Moving Average DataFrame based on the input data

    Inputs:
        data: A Pandas DataFrame Series
        period: length of the Simple Moving Average
"""
def sma(data, period):

    data_series = pd.Series(data)
    window = data_series.rolling(period)
    moving_averages = window.mean()

    moving_averages_list = moving_averages.tolist()

    df_sma = pd.DataFrame(moving_averages_list, columns=['sma'])
    df_sma['sma'] = df_sma['sma'].fillna(0)
    df_sma.index = data.index
    return df_sma.iloc[period:]['sma']

# %%
# Import and format data
btc_data = pd.read_csv('./data/btcusd.csv')
btc_data['Date'] = pd.to_datetime(btc_data['Date'])
btc_data = btc_data.set_index('Date')
btc_data = btc_data[(btc_data.index > '2020-01-01') & (btc_data.index <= '2021-10-01')]
btc_data = btc_data.iloc[::10]
btc_data = btc_data.iloc[::-1] # reverse dataframe

eth_data = pd.read_csv('./data/ethusd.csv')
eth_data['Date'] = pd.to_datetime(eth_data['Date'])
eth_data = eth_data.set_index('Date')
eth_data = eth_data[(eth_data.index > '2020-01-01') & (eth_data.index <= '2021-10-01')]
eth_data = eth_data.iloc[::10]
eth_data = eth_data.iloc[::-1]

# %%
x = btc_data['Close']
y = eth_data['Close']
df = pd.concat([x, y], axis=1)
df.columns = ['BTC', 'ETH']
df.head()
# Out:
#                          BTC     ETH
# Date
# 2020-01-01 06:00:00  7206.67  130.03
# 2020-01-01 16:00:00  7225.00  132.52
# 2020-01-02 02:00:00  7141.03  129.37
# 2020-01-02 12:00:00  7133.24  129.59
# 2020-01-02 22:00:00  6952.51  126.92

# %% [markdown]
# ## Plotting Bitcoin and Ethereum. There's clearly a positive correlation between the two assets.

# %%
# %matplotlib inline
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.plot(df.BTC, color = 'blue', label="Bitcoin")
ax2 = ax.twinx()
ax2.plot(df.ETH, color = 'green', label="Ethereum")
plt.title("Bitcoin and Ethereum")
# Out:
# Text(0.5, 1.0, 'Bitcoin and Ethereum')

# %% [markdown]
# ## Calculating the Spread

# %%
model = sm.OLS(df.BTC.iloc[:400], df.ETH.iloc[:400])
model = model.fit()
print(model.params[0])
# Out:
# 14.68899466410953

# %%
df['spread'] = df.BTC - model.params[0] * df.ETH

df.spread.plot(figsize=(8, 4))
plt.ylabel("Spread")
plt.show()

# %%
# Perform ADF Test
from statsmodels.tsa.stattools import adfuller
# Compute ADF test statistics
adf = adfuller(df.spread, maxlag = 1)
adf[0]
# Out:
# -4.073540992760117

# %%
adf[4]
# Out:
# {'1%': -3.448343869853195, '5%': -2.869469418606909, '10%': -2.570994248260623}

# %% [markdown]
# Conclusion: Since -4.08 < -3.44, Portfolio is Stationary and BTC & ETH cointegrated with >99% certainty

# %% [markdown]
# # Cointegration Trading Strategy

# %%
gross_returns = np.array([])
net_returns = np.array([])
t_s = np.array([])
window = 250
fee = 0.0001
t_threshold = -2.5
data = pd.DataFrame()
returns = pd.DataFrame()
data['BTC'] = df.BTC
data['ETH'] = df.ETH
returns['BTC'] = data['BTC'][1:].reset_index(drop=True) / data['BTC'][:-1].reset_index(drop=True)
returns['ETH'] = data['ETH'][1:].reset_index(drop=True) / data['ETH'][:-1].reset_index(drop=True)
times = df.index
asset1 = 'BTC'
asset2 = 'ETH'
for t in range(window, len(data[asset1])-10):
    #define unit root function: stock2 = a + b * stock1
    def unit_root(b):
        a = np.average(data[asset2][t-window:t] - b*data[asset1][t-window:t])
        fair_value = a + b*data[asset1][t-window:t]
        diff = np.array(fair_value - data[asset2][t-window:t])
        diff_diff = diff[1:] - diff[:-1]
        reg = sm.OLS(diff_diff, diff[:-1])
        res = reg.fit()
        return res.params[0]/res.bse[0]
    res1 = spop.minimize(unit_root, data[asset2][t]/data[asset1][t], method='Nelder-Mead')
    t_opt = res1.fun
    b_opt = float(res1.x)
    a_opt = np.average(data[asset2][t-window:t] - b_opt*data[asset1][t-window:t])
    fair_value = a_opt + b_opt*data[asset1][t]
    
    #optimising the cointegration equation parameters
    if t == window:
        old_signal = 0
    if t_opt > t_threshold:
        signal = 0
        gross_return = 0
    else:
        signal = np.sign(fair_value - data[asset2][t])
        gross_return = signal*returns[asset2][t] - signal*returns[asset1][t]
    fees = fee*abs(signal - old_signal)
    net_return = gross_return - fees
    gross_returns = np.append(gross_returns, gross_return)
    net_returns = np.append(net_returns, net_return)
    t_s = np.append(t_s, t_opt)
    #simulating trading
    print(f"day {str(data.index[t])}")
    print('')
    if signal == 0:
        print("no trading")
    elif signal == 1:
        print(f"long position on {asset2} and short position on {asset1}")
    else:
        print(f"long position on {asset1} and short position on {asset2}")
    print(f"gross daily return: {str(round(gross_return*100, 2))}%")
    print(f"net daily return: {str(round(net_return*100, 2))}%")
    print(f"cumulative net return so far: {str(round(np.prod(1+net_returns)*100-100, 2))}%")
    print('')
    old_signal = signal

plt.plot(np.append(1, np.cumprod(1+gross_returns)))
plt.plot(np.append(1, np.cumprod(1+net_returns)))
# Out:
# day 2020-04-14 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-14 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-15 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-15 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-16 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-16 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-16 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-17 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-17 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-18 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-18 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-19 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-19 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-20 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-20 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-21 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-21 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-21 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-22 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-22 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-23 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-23 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-24 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-24 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-25 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-25 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-26 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-26 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-26 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-27 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-27 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-28 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-28 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-29 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-29 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-30 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-04-30 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-01 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-01 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-01 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-02 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-02 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-03 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-03 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-04 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-04 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-05 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-05 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-06 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-06 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-06 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-07 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-07 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-08 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-08 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-09 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-09 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-10 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-10 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-11 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-11 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-11 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-05-12 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.2%
# net daily return: -1.21%
# cumulative net return so far: -1.21%
#
# day 2020-05-12 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.42%
# net daily return: -0.42%
# cumulative net return so far: -1.63%
#
# day 2020-05-13 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.42%
# net daily return: 1.42%
# cumulative net return so far: -0.23%
#
# day 2020-05-13 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.38%
# net daily return: -1.38%
# cumulative net return so far: -1.6%
#
# day 2020-05-14 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -2.01%
# net daily return: -2.01%
# cumulative net return so far: -3.58%
#
# day 2020-05-14 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -3.59%
#
# day 2020-05-14 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-15 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-15 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-16 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-16 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-16 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-17 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-17 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-18 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-18 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-19 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-19 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-20 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-20 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-21 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-21 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-21 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-22 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-22 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-23 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-23 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-24 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-24 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-25 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-25 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-26 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-26 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-26 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-27 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-27 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-28 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-28 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-29 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-29 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-30 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-30 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-31 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-31 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-05-31 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-06-01 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-06-01 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-06-02 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -3.59%
#
# day 2020-06-02 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.99%
# net daily return: -2.0%
# cumulative net return so far: -5.52%
#
# day 2020-06-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -5.53%
#
# day 2020-06-03 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-03 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-04 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-04 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-05 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-05 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-05 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-06 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.53%
#
# day 2020-06-06 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.27%
# net daily return: -0.28%
# cumulative net return so far: -5.8%
#
# day 2020-06-07 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.03%
# net daily return: -0.03%
# cumulative net return so far: -5.83%
#
# day 2020-06-07 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -5.84%
#
# day 2020-06-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-08 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-08 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-09 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-09 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-10 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-10 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-10 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-11 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-11 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-12 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-12 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-13 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-13 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-14 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-14 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-15 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-15 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-15 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-16 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-16 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-17 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-17 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-18 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-18 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-19 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-19 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-20 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-20 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-20 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-21 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-21 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-22 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-22 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-23 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-23 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-24 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-24 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-25 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-25 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-25 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-26 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-26 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-27 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-27 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-28 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-28 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-29 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-29 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-30 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-30 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-06-30 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-01 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-01 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-02 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-02 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-03 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-03 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-04 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-04 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-05 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-05 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-05 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-06 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-06 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-07 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-07 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-08 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-08 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-09 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-09 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-10 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-10 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-10 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-11 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-11 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-12 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-12 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-13 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-13 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-14 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-14 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-15 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-15 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-15 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-16 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-16 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-17 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-17 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -5.84%
#
# day 2020-07-18 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.6%
# net daily return: -0.61%
# cumulative net return so far: -6.42%
#
# day 2020-07-18 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.49%
# net daily return: 0.49%
# cumulative net return so far: -5.96%
#
# day 2020-07-19 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.07%
# net daily return: -0.07%
# cumulative net return so far: -6.03%
#
# day 2020-07-19 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -6.04%
#
# day 2020-07-20 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-20 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-20 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-21 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-21 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-22 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-22 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-23 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-23 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-24 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-24 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-25 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -6.04%
#
# day 2020-07-25 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 6.67%
# net daily return: 6.66%
# cumulative net return so far: 0.22%
#
# day 2020-07-25 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: 0.21%
#
# day 2020-07-26 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -3.94%
# net daily return: -3.95%
# cumulative net return so far: -3.75%
#
# day 2020-07-26 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.92%
# net daily return: 1.92%
# cumulative net return so far: -1.91%
#
# day 2020-07-27 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -3.34%
# net daily return: -3.34%
# cumulative net return so far: -5.18%
#
# day 2020-07-27 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -5.36%
# net daily return: -5.36%
# cumulative net return so far: -10.26%
#
# day 2020-07-28 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.41%
# net daily return: -0.41%
# cumulative net return so far: -10.63%
#
# day 2020-07-28 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -10.64%
#
# day 2020-07-28 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.07%
# net daily return: 0.06%
# cumulative net return so far: -10.59%
#
# day 2020-07-29 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -2.02%
# net daily return: -2.02%
# cumulative net return so far: -12.4%
#
# day 2020-07-29 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -12.4%
#
# day 2020-07-30 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -12.4%
#
# day 2020-07-30 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 3.02%
# net daily return: 3.01%
# cumulative net return so far: -9.77%
#
# day 2020-07-30 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.61%
# net daily return: 1.61%
# cumulative net return so far: -8.31%
#
# day 2020-07-31 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.2%
# net daily return: 0.2%
# cumulative net return so far: -8.13%
#
# day 2020-07-31 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 2.08%
# net daily return: 2.08%
# cumulative net return so far: -6.22%
#
# day 2020-08-01 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.25%
# net daily return: -1.25%
# cumulative net return so far: -7.39%
#
# day 2020-08-01 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 7.45%
# net daily return: 7.45%
# cumulative net return so far: -0.49%
#
# day 2020-08-02 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.56%
# net daily return: 0.56%
# cumulative net return so far: 0.07%
#
# day 2020-08-02 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.34%
# net daily return: -1.36%
# cumulative net return so far: -1.28%
#
# day 2020-08-02 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.01%
# net daily return: -2.01%
# cumulative net return so far: -3.27%
#
# day 2020-08-03 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.29%
# net daily return: 0.27%
# cumulative net return so far: -3.01%
#
# day 2020-08-03 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.3%
# net daily return: 1.3%
# cumulative net return so far: -1.75%
#
# day 2020-08-04 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.05%
# net daily return: 0.05%
# cumulative net return so far: -1.71%
#
# day 2020-08-04 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: -1.43%
#
# day 2020-08-04 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.09%
# net daily return: -1.09%
# cumulative net return so far: -2.51%
#
# day 2020-08-05 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.67%
# net daily return: -1.67%
# cumulative net return so far: -4.14%
#
# day 2020-08-05 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.21%
# net daily return: -0.21%
# cumulative net return so far: -4.35%
#
# day 2020-08-06 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.87%
# net daily return: -0.87%
# cumulative net return so far: -5.18%
#
# day 2020-08-06 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.47%
# net daily return: -0.47%
# cumulative net return so far: -5.63%
#
# day 2020-08-07 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: -5.72%
#
# day 2020-08-07 10:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -2.33%
# net daily return: -2.33%
# cumulative net return so far: -7.91%
#
# day 2020-08-07 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.52%
# net daily return: 0.52%
# cumulative net return so far: -7.43%
#
# day 2020-08-08 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.75%
# net daily return: 1.75%
# cumulative net return so far: -5.81%
#
# day 2020-08-08 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.99%
# net daily return: 0.99%
# cumulative net return so far: -4.88%
#
# day 2020-08-09 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.07%
# net daily return: -1.07%
# cumulative net return so far: -5.9%
#
# day 2020-08-09 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.14%
# net daily return: -0.14%
# cumulative net return so far: -6.04%
#
# day 2020-08-09 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.78%
# net daily return: -0.78%
# cumulative net return so far: -6.77%
#
# day 2020-08-10 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.86%
# net daily return: 0.86%
# cumulative net return so far: -5.96%
#
# day 2020-08-10 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.11%
# net daily return: 0.11%
# cumulative net return so far: -5.86%
#
# day 2020-08-11 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.19%
# net daily return: -0.19%
# cumulative net return so far: -6.04%
#
# day 2020-08-11 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -6.28%
#
# day 2020-08-12 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.23%
# net daily return: 0.23%
# cumulative net return so far: -6.06%
#
# day 2020-08-12 10:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.2%
# net daily return: 0.2%
# cumulative net return so far: -5.87%
#
# day 2020-08-12 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.62%
# net daily return: 1.62%
# cumulative net return so far: -4.34%
#
# day 2020-08-13 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: -4.1%
#
# day 2020-08-13 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 5.99%
# net daily return: 5.99%
# cumulative net return so far: 1.65%
#
# day 2020-08-14 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.89%
# net daily return: -0.91%
# cumulative net return so far: 0.73%
#
# day 2020-08-14 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.64%
# net daily return: -2.64%
# cumulative net return so far: -1.93%
#
# day 2020-08-14 22:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.91%
# net daily return: 1.91%
# cumulative net return so far: -0.06%
#
# day 2020-08-15 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.33%
# net daily return: -0.33%
# cumulative net return so far: -0.39%
#
# day 2020-08-15 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.83%
# net daily return: 1.83%
# cumulative net return so far: 1.43%
#
# day 2020-08-16 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.3%
# net daily return: -0.32%
# cumulative net return so far: 1.1%
#
# day 2020-08-16 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.27%
# net daily return: -1.29%
# cumulative net return so far: -0.2%
#
# day 2020-08-17 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.23%
# net daily return: 1.23%
# cumulative net return so far: 1.03%
#
# day 2020-08-17 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: 2.09%
#
# day 2020-08-17 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.22%
# net daily return: -1.24%
# cumulative net return so far: 0.82%
#
# day 2020-08-18 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.62%
# net daily return: 0.62%
# cumulative net return so far: 1.44%
#
# day 2020-08-18 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.11%
# net daily return: -0.11%
# cumulative net return so far: 1.33%
#
# day 2020-08-19 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.51%
# net daily return: -1.51%
# cumulative net return so far: -0.21%
#
# day 2020-08-19 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.27%
# net daily return: -0.27%
# cumulative net return so far: -0.48%
#
# day 2020-08-19 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.29%
# net daily return: -0.29%
# cumulative net return so far: -0.76%
#
# day 2020-08-20 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.62%
# net daily return: 1.62%
# cumulative net return so far: 0.84%
#
# day 2020-08-20 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.64%
# net daily return: 0.62%
# cumulative net return so far: 1.47%
#
# day 2020-08-21 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.01%
# net daily return: -1.03%
# cumulative net return so far: 0.43%
#
# day 2020-08-21 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -3.25%
# net daily return: -3.25%
# cumulative net return so far: -2.83%
#
# day 2020-08-22 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.4%
# net daily return: 1.4%
# cumulative net return so far: -1.48%
#
# day 2020-08-22 10:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.0%
# net daily return: -1.0%
# cumulative net return so far: -2.46%
#
# day 2020-08-22 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -1.79%
#
# day 2020-08-23 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.66%
# net daily return: -0.66%
# cumulative net return so far: -2.43%
#
# day 2020-08-23 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: -2.26%
#
# day 2020-08-24 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 2.57%
# net daily return: 2.57%
# cumulative net return so far: 0.25%
#
# day 2020-08-24 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.52%
# net daily return: 0.52%
# cumulative net return so far: 0.77%
#
# day 2020-08-24 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.38%
# net daily return: -1.38%
# cumulative net return so far: -0.62%
#
# day 2020-08-25 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.38%
# net daily return: -1.38%
# cumulative net return so far: -2.0%
#
# day 2020-08-25 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.85%
# net daily return: -0.87%
# cumulative net return so far: -2.85%
#
# day 2020-08-26 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: -2.46%
#
# day 2020-08-26 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: -2.77%
#
# day 2020-08-27 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: -2.39%
#
# day 2020-08-27 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: -2.0%
#
# day 2020-08-27 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.65%
# net daily return: -1.65%
# cumulative net return so far: -3.62%
#
# day 2020-08-28 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.57%
# net daily return: -0.57%
# cumulative net return so far: -4.17%
#
# day 2020-08-28 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.38%
# net daily return: 0.38%
# cumulative net return so far: -3.8%
#
# day 2020-08-29 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.52%
# net daily return: -1.52%
# cumulative net return so far: -5.27%
#
# day 2020-08-29 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.31%
# net daily return: -0.31%
# cumulative net return so far: -5.56%
#
# day 2020-08-29 22:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.01%
# net daily return: -0.01%
# cumulative net return so far: -5.58%
#
# day 2020-08-30 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -5.01%
# net daily return: -5.01%
# cumulative net return so far: -10.3%
#
# day 2020-08-30 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -9.69%
#
# day 2020-08-31 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.08%
# net daily return: -2.08%
# cumulative net return so far: -11.56%
#
# day 2020-08-31 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.6%
# net daily return: -0.6%
# cumulative net return so far: -12.09%
#
# day 2020-09-01 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -5.9%
# net daily return: -5.9%
# cumulative net return so far: -17.28%
#
# day 2020-09-01 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.87%
# net daily return: -1.87%
# cumulative net return so far: -18.82%
#
# day 2020-09-01 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.1%
# net daily return: 0.1%
# cumulative net return so far: -18.74%
#
# day 2020-09-02 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 5.49%
# net daily return: 5.49%
# cumulative net return so far: -14.28%
#
# day 2020-09-02 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -3.52%
# net daily return: -3.52%
# cumulative net return so far: -17.3%
#
# day 2020-09-03 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 2.45%
# net daily return: 2.45%
# cumulative net return so far: -15.28%
#
# day 2020-09-03 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 2.47%
# net daily return: 2.47%
# cumulative net return so far: -13.18%
#
# day 2020-09-03 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -13.19%
#
# day 2020-09-04 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 3.04%
# net daily return: 3.03%
# cumulative net return so far: -10.55%
#
# day 2020-09-04 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -10.56%
#
# day 2020-09-05 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -10.56%
#
# day 2020-09-05 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -10.56%
#
# day 2020-09-06 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.66%
# net daily return: -2.67%
# cumulative net return so far: -12.96%
#
# day 2020-09-06 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.77%
# net daily return: -0.77%
# cumulative net return so far: -13.63%
#
# day 2020-09-06 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.88%
# net daily return: 1.88%
# cumulative net return so far: -12.0%
#
# day 2020-09-07 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.02%
# net daily return: -1.02%
# cumulative net return so far: -12.91%
#
# day 2020-09-07 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.39%
# net daily return: 0.39%
# cumulative net return so far: -12.56%
#
# day 2020-09-08 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.81%
# net daily return: 0.81%
# cumulative net return so far: -11.85%
#
# day 2020-09-08 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.24%
# net daily return: 1.24%
# cumulative net return so far: -10.76%
#
# day 2020-09-08 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -10.76%
#
# day 2020-09-09 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -3.24%
# net daily return: -3.25%
# cumulative net return so far: -13.66%
#
# day 2020-09-09 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -3.61%
# net daily return: -3.61%
# cumulative net return so far: -16.78%
#
# day 2020-09-10 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.31%
# net daily return: 1.31%
# cumulative net return so far: -15.69%
#
# day 2020-09-10 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -15.7%
#
# day 2020-09-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -15.7%
#
# day 2020-09-11 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -15.7%
#
# day 2020-09-11 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# ...
#
# long position on ETH and short position on BTC
# gross daily return: 0.26%
# net daily return: 0.24%
# cumulative net return so far: -10.69%
#
# day 2021-08-13 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -10.92%
#
# day 2021-08-14 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.24%
# net daily return: 0.24%
# cumulative net return so far: -10.71%
#
# day 2021-08-14 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.62%
# net daily return: -0.62%
# cumulative net return so far: -11.26%
#
# day 2021-08-14 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.46%
# net daily return: -0.46%
# cumulative net return so far: -11.67%
#
# day 2021-08-15 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.11%
# net daily return: 0.11%
# cumulative net return so far: -11.58%
#
# day 2021-08-15 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: -11.3%
#
# day 2021-08-16 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.55%
# net daily return: 0.55%
# cumulative net return so far: -10.81%
#
# day 2021-08-16 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.55%
# net daily return: -1.55%
# cumulative net return so far: -12.19%
#
# day 2021-08-17 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: -11.24%
#
# day 2021-08-17 10:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.3%
# net daily return: -1.3%
# cumulative net return so far: -12.39%
#
# day 2021-08-17 20:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.9%
# net daily return: -0.9%
# cumulative net return so far: -13.18%
#
# day 2021-08-18 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: -12.72%
#
# day 2021-08-18 16:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.75%
# net daily return: -0.75%
# cumulative net return so far: -13.37%
#
# day 2021-08-19 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: -13.65%
#
# day 2021-08-19 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.78%
# net daily return: 0.78%
# cumulative net return so far: -12.97%
#
# day 2021-08-19 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.65%
# net daily return: 0.65%
# cumulative net return so far: -12.41%
#
# day 2021-08-20 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -2.21%
# net daily return: -2.21%
# cumulative net return so far: -14.35%
#
# day 2021-08-20 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.78%
# net daily return: 0.78%
# cumulative net return so far: -13.67%
#
# day 2021-08-21 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.18%
# net daily return: -1.18%
# cumulative net return so far: -14.69%
#
# day 2021-08-21 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.28%
# net daily return: -0.28%
# cumulative net return so far: -14.93%
#
# day 2021-08-22 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.15%
# net daily return: -0.15%
# cumulative net return so far: -15.06%
#
# day 2021-08-22 10:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.59%
# net daily return: -1.59%
# cumulative net return so far: -16.42%
#
# day 2021-08-22 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.96%
# net daily return: -1.98%
# cumulative net return so far: -18.07%
#
# day 2021-08-23 06:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 1.64%
# net daily return: 1.62%
# cumulative net return so far: -16.75%
#
# day 2021-08-23 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -16.75%
#
# day 2021-08-24 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.05%
# net daily return: -0.06%
# cumulative net return so far: -16.8%
#
# day 2021-08-24 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.01%
# net daily return: 1.01%
# cumulative net return so far: -15.96%
#
# day 2021-08-24 22:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.3%
# net daily return: 1.3%
# cumulative net return so far: -14.87%
#
# day 2021-08-25 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.65%
# net daily return: -0.65%
# cumulative net return so far: -15.43%
#
# day 2021-08-25 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.16%
# net daily return: 0.16%
# cumulative net return so far: -15.29%
#
# day 2021-08-26 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.84%
# net daily return: -0.84%
# cumulative net return so far: -16.0%
#
# day 2021-08-26 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.96%
# net daily return: 0.96%
# cumulative net return so far: -15.2%
#
# day 2021-08-27 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.13%
# net daily return: 0.13%
# cumulative net return so far: -15.09%
#
# day 2021-08-27 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.37%
# net daily return: -1.37%
# cumulative net return so far: -16.25%
#
# day 2021-08-27 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.61%
# net daily return: 0.61%
# cumulative net return so far: -15.74%
#
# day 2021-08-28 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.08%
# net daily return: -0.08%
# cumulative net return so far: -15.81%
#
# day 2021-08-28 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.2%
# net daily return: -0.2%
# cumulative net return so far: -15.98%
#
# day 2021-08-29 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.56%
# net daily return: -0.58%
# cumulative net return so far: -16.47%
#
# day 2021-08-29 12:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.3%
# net daily return: -0.3%
# cumulative net return so far: -16.72%
#
# day 2021-08-29 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.8%
# net daily return: 0.8%
# cumulative net return so far: -16.05%
#
# day 2021-08-30 08:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -3.19%
# net daily return: -3.21%
# cumulative net return so far: -18.75%
#
# day 2021-08-30 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.22%
# net daily return: -0.22%
# cumulative net return so far: -18.93%
#
# day 2021-08-31 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -4.08%
# net daily return: -4.08%
# cumulative net return so far: -22.24%
#
# day 2021-08-31 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.73%
# net daily return: -1.73%
# cumulative net return so far: -23.58%
#
# day 2021-09-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -23.59%
#
# day 2021-09-01 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-01 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-02 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-02 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-03 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-03 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-03 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-04 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-04 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-05 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-05 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-06 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-06 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-07 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-07 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-08 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-08 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-08 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-09 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-09 18:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-10 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-10 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-11 10:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-11 20:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-12 06:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-12 16:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-13 02:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-13 12:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-13 22:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-14 08:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.59%
#
# day 2021-09-14 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.49%
# net daily return: -0.5%
# cumulative net return so far: -23.97%
#
# day 2021-09-15 04:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.01%
# cumulative net return so far: -23.98%
#
# day 2021-09-15 14:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.98%
#
# day 2021-09-16 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.51%
# net daily return: -0.52%
# cumulative net return so far: -24.38%
#
# day 2021-09-16 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.28%
# net daily return: 1.28%
# cumulative net return so far: -23.41%
#
# day 2021-09-16 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: -23.49%
#
# day 2021-09-17 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 2.22%
# net daily return: 2.22%
# cumulative net return so far: -21.79%
#
# day 2021-09-17 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.18%
# net daily return: 1.18%
# cumulative net return so far: -20.87%
#
# day 2021-09-18 02:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.53%
# net daily return: 0.51%
# cumulative net return so far: -20.46%
#
# day 2021-09-18 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.33%
# net daily return: 1.31%
# cumulative net return so far: -19.42%
#
# day 2021-09-18 22:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.25%
# net daily return: 0.23%
# cumulative net return so far: -19.24%
#
# day 2021-09-19 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -1.12%
# net daily return: -1.12%
# cumulative net return so far: -20.14%
#
# day 2021-09-19 18:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.59%
# net daily return: -0.59%
# cumulative net return so far: -20.61%
#
# day 2021-09-20 04:00:00
#
# long position on ETH and short position on BTC
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: -20.89%
#
# day 2021-09-20 14:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.02%
# net daily return: 1.0%
# cumulative net return so far: -20.1%
#
# day 2021-09-21 00:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.9%
# net daily return: -2.9%
# cumulative net return so far: -22.42%
#
# day 2021-09-21 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 4.55%
# net daily return: 4.55%
# cumulative net return so far: -18.89%
#
# day 2021-09-21 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -2.54%
# net daily return: -2.54%
# cumulative net return so far: -20.95%
#
# day 2021-09-22 06:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -1.43%
# net daily return: -1.43%
# cumulative net return so far: -22.08%
#
# day 2021-09-22 16:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.28%
# net daily return: -0.28%
# cumulative net return so far: -22.3%
#
# day 2021-09-23 02:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -0.19%
# net daily return: -0.19%
# cumulative net return so far: -22.45%
#
# day 2021-09-23 12:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.64%
# net daily return: 0.64%
# cumulative net return so far: -21.95%
#
# day 2021-09-23 22:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 2.1%
# net daily return: 2.1%
# cumulative net return so far: -20.31%
#
# day 2021-09-24 08:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.0%
# net daily return: -0.02%
# cumulative net return so far: -20.33%
#
# day 2021-09-24 18:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.01%
# net daily return: -0.01%
# cumulative net return so far: -20.34%
#
# day 2021-09-25 04:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: -19.47%
#
# day 2021-09-25 14:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.22%
# net daily return: 0.2%
# cumulative net return so far: -19.31%
#
# day 2021-09-26 00:00:00
#
# long position on ETH and short position on BTC
# gross daily return: 0.96%
# net daily return: 0.96%
# cumulative net return so far: -18.53%
#
# day 2021-09-26 10:00:00
#
# long position on BTC and short position on ETH
# gross daily return: -3.11%
# net daily return: -3.13%
# cumulative net return so far: -21.08%
#
# day 2021-09-26 20:00:00
#
# long position on BTC and short position on ETH
# gross daily return: 0.14%
# net daily return: 0.14%
# cumulative net return so far: -20.97%

# %%
# %matplotlib inline
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.plot(df.BTC, color = 'blue', label="Bitcoin")
ax2 = ax.twinx()
ax2.plot(df.ETH, color = 'green', label="Ethereum")
plt.title("Bitcoin and Ethereum")
# Out:
# Text(0.5, 1.0, 'Bitcoin and Ethereum')

# %%
returns['BTC'][4]
# Out:
# 1.016911590338856
